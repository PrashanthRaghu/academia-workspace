# %% [markdown]
# # Introduction to Pandas ( Contd. )
#
# License:
# Created by: Prashanth Raghu, Gonagoor Technology Llp. Assisted by: Phaneendra V.
# It’s okay to share amongst the student community and learn from it. Don’t worry. It’s under
# Creative License. Just drop a reference to this document and author names if you use it anywhere.
#
# For commercial use,
# drop an email to p.is.prashanth [at] gmail [dot] com

# %%
import pandas as pd

# %%
rainfalls = pd.read_csv('data-sets/rainfall.csv')

# %%
rainfalls.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  Andaman & Nicobar Islands  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  Andaman & Nicobar Islands  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  Andaman & Nicobar Islands  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  Andaman & Nicobar Islands  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  Andaman & Nicobar Islands  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF    MAM    JJAS  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2  136.3  560.3  1696.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7  159.8  458.3  2185.9
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4  156.7  236.1  1874.0
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6   24.1  506.9  1977.6
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7    1.3  309.7  1624.9
#
#      OND
# 0  980.3
# 1  716.7
# 2  690.6
# 3  571.0
# 4  630.8

# %% [markdown]
# Data Sources
# --
#
# Data Sources allow the data to be analysed from different input formats.
# Ex: CSV, JSON, XML, Excel, Open Office Formats, HDFS to name a few.
#
# Pandas allows us to seemlessly work between data formats.

# %%
rainfalls.to_json('data-sets/rainfall-1.json', index=False)

# %%
rainfalls_js = pd.read_json('data-sets/rainfall-1.json')

# %%
rainfalls_js.shape
# Out:
# (4188, 19)

# %%
rainfalls_js.to_html('data-sets/rainfall-1.html')

# %%
rainfalls.index
# Out:
# RangeIndex(start=0, stop=4188, step=1)

# %%
rainfalls.reindex(range(1, 4100))
# Out:
#                     SUBDIVISION  YEAR    JAN    FEB   MAR    APR    MAY  \
# 1     Andaman & Nicobar Islands  1902    0.0  159.8  12.2    0.0  446.1
# 2     Andaman & Nicobar Islands  1903   12.7  144.0   0.0    1.0  235.1
# 3     Andaman & Nicobar Islands  1904    9.4   14.7   0.0  202.4  304.5
# 4     Andaman & Nicobar Islands  1905    1.3    0.0   3.3   26.9  279.5
# 5     Andaman & Nicobar Islands  1906   36.6    0.0   0.0    0.0  556.1
# ...                         ...   ...    ...    ...   ...    ...    ...
# 4095                Lakshadweep  1925    2.3    7.5  15.5   32.6  244.2
# 4096                Lakshadweep  1926  262.8   16.0  33.6   60.2  335.8
# 4097                Lakshadweep  1927  108.2   14.7  40.7   40.4  229.0
# 4098                Lakshadweep  1928   42.5   66.6   NaN    1.4  212.3
# 4099                Lakshadweep  1929    6.1   66.6  49.5   91.0  248.0
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF    MAM  \
# ...

# %%
pivot = rainfalls.pivot(index=["YEAR"], columns=["SUBDIVISION"], values=["JAN"])

# %%
pivot
# Out:
#                                   JAN                                      \
# SUBDIVISION Andaman & Nicobar Islands Arunachal Pradesh Assam & Meghalaya
# YEAR
# 1901                             49.2               NaN              27.1
# 1902                              0.0               NaN               9.3
# 1903                             12.7               NaN              19.9
# 1904                              9.4               NaN              11.1
# 1905                              1.3               NaN              19.9
# ...                               ...               ...               ...
# 2013                             67.1              18.5               1.1
# 2014                             41.9              19.0               2.0
# 2015                            126.8              30.8              13.4
# 2016                             72.0              29.4              18.9
# 2017                            228.7               8.2               1.7
#
# ...

# %%
pivot2 = rainfalls.pivot(index=["YEAR"], columns=["SUBDIVISION"], values=["JAN", "FEB",])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 pivot2 = rainfalls.pivot(index=["YEAR"], values=["SUBDIVISION"], columns=["JAN", "FEB", "MAR"])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:9025, in DataFrame.pivot(self, columns, index, values)
#    9018 @Substitution("")
#    9019 @Appender(_shared_docs["pivot"])
#    9020 def pivot(
#    9021     self, *, columns, index=lib.no_default, values=lib.no_default
#    9022 ) -> DataFrame:
#    9023     from pandas.core.reshape.pivot import pivot
# -> 9025     return pivot(self, index=index, columns=columns, values=values)
#
# ...

# %%
pivot2
# Out:
#                                   JAN                                      \
# SUBDIVISION Andaman & Nicobar Islands Arunachal Pradesh Assam & Meghalaya
# YEAR
# 1901                             49.2               NaN              27.1
# 1902                              0.0               NaN               9.3
# 1903                             12.7               NaN              19.9
# 1904                              9.4               NaN              11.1
# 1905                              1.3               NaN              19.9
# ...                               ...               ...               ...
# 2013                             67.1              18.5               1.1
# 2014                             41.9              19.0               2.0
# 2015                            126.8              30.8              13.4
# 2016                             72.0              29.4              18.9
# 2017                            228.7               8.2               1.7
#
# ...

# %%
pivot2["JAN"]["Bihar"][2015]
# Out:
# 12.8
